# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import pandas as pd
from scipy.fft import fft
import scipy.signal as signal
from math import log10
from scipy.signal import butter, lfilter
from scipy.stats import linregress
from statistics import mean

# %%
pip install biosignalsnotebooks
# Out:
# Collecting biosignalsnotebooks
#   Downloading biosignalsnotebooks-0.6.11-py3-none-any.whl (39.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.1/39.1 MB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (1.10.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (3.8.0)
# Collecting wget (from biosignalsnotebooks)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting datetime (from biosignalsnotebooks)
#   Downloading DateTime-5.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (2.4.3)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (7.34.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (1.5.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (5.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from biosignalsnotebooks) (2.27.1)
# Collecting libmagic (from biosignalsnotebooks)
#   Downloading libmagic-1.0.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-magic (from biosignalsnotebooks)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->biosignalsnotebooks) (3.1.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->biosignalsnotebooks) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->biosignalsnotebooks) (8.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->biosignalsnotebooks) (6.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->biosignalsnotebooks) (6.3.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->biosignalsnotebooks) (4.6.3)
# Collecting zope.interface (from datetime->biosignalsnotebooks)
#   Downloading zope.interface-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 26.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datetime->biosignalsnotebooks) (2022.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (67.7.2)
# Collecting jedi>=0.16 (from IPython->biosignalsnotebooks)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->biosignalsnotebooks) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosignalsnotebooks) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosignalsnotebooks) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosignalsnotebooks) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosignalsnotebooks) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosignalsnotebooks) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->biosignalsnotebooks) (2.8.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->biosignalsnotebooks) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->biosignalsnotebooks) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat->biosignalsnotebooks) (5.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->biosignalsnotebooks) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->biosignalsnotebooks) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->biosignalsnotebooks) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->biosignalsnotebooks) (3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->biosignalsnotebooks) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->biosignalsnotebooks) (2.1.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->biosignalsnotebooks) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->biosignalsnotebooks) (0.19.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->biosignalsnotebooks) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->biosignalsnotebooks) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->biosignalsnotebooks) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat->biosignalsnotebooks) (3.7.0)
# Building wheels for collected packages: libmagic, wget
#   Building wheel for libmagic (setup.py) ... done
#   Created wheel for libmagic: filename=libmagic-1.0-py3-none-any.whl size=4269 sha256=ddec77a89f8da51af20e27f82b3773372215a86be70d7bacf26a48a6c01250e9
#   Stored in directory: /root/.cache/pip/wheels/31/ce/d8/099fbd4dbfa5da5596a39eee8a17d2e1bcc29006c07d3563b7
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=03b7fd65be5c32d88eea24674f4813d8e7b30c79898a63a3160c7a18d437756b
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built libmagic wget
# Installing collected packages: wget, libmagic, zope.interface, python-magic, jedi, datetime, biosignalsnotebooks
# Successfully installed biosignalsnotebooks-0.6.11 datetime-5.1 jedi-0.18.2 libmagic-1.0 python-magic-0.4.27 wget-3.2 zope.interface-6.0

# %%
import biosignalsnotebooks as bsnb

# %%
array1 = np.genfromtxt("p2_ulnar.txt",   skip_header=1, delimiter="\t")
Fs = 1000
Ts = 1/Fs
señal = array1[:,-2]
señalP = señal[4000:14000]
n = len(señalP)
t = np.arange(4000,4000+n,1)*Ts
plt.figure(figsize=(20,5))
plt.plot(t, señalP)
plt.xlabel("Tiempo [segundos]")
plt.title("Ulnar P2")
# Out:
# Text(0.5, 1.0, 'Ulnar P2')

# %% [markdown]
# ## Adapatación de la señal

# %%
vcc  = 3300 #mV
gain = 1009
resolution = 10
señal = array1[:,-2]
nseñal = (((señal / 2**resolution) - 0.5) * vcc) / gain
nseñal = nseñal[4000:14000]
print(nseñal)
plt.figure(figsize=(20,5))
plt.plot(nseñal)
plt.ylabel("mV")
plt.xlabel("Tiempo [ms]")
plt.title("Señal EMG ulnar")
# Out:
# [-0.02555129 -0.02555129 -0.02555129 ... -0.07026604 -0.01596956
#   0.01596956]
# Text(0.5, 1.0, 'Señal EMG ulnar')

# %% [markdown]
# ## DETECCIÓN DE EVENTOS

# %%
# Eliminacion de la linea de Base

#average = sum(señalP)/len(señalP)
#pre_pro_signal = señalP - average
pre_pro_signal2 = nseñal - np.average(nseñal)
pre_pro_signal2

señalP = pre_pro_signal2
n = len(señalP)
t = np.arange(0,0+n,1)*Ts
plt.figure(figsize=(20,5))
plt.plot(t, señalP)
plt.ylabel("mV")
plt.xlabel("Tiempo [segundos]")
plt.title("Ulnar P2")
# Out:
# Text(0.5, 1.0, 'Ulnar P2')

# %%
# Analizar el Fourier
emg_senal = pre_pro_signal2
Fs = 1000
Ts = 1/Fs
N = len(emg_senal)
yf = fft(emg_senal)
xf = np.linspace(0.0, 1.0/(2.0*Ts), N//2)
plt.figure(figsize=(15,5))
ejy = 2.0/N * np.abs(yf[0:N//2])
plt.plot(xf, ejy )
plt.grid()
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("Magnitud")
plt.title("Espectro de Magnitud de la señal EMG")
plt.xlim(-10,500)
plt.show()

# %%
from scipy.signal import iirnotch, lfilter
f0 = 60.0  # Frecuencia que queremos filtrar (Hz)
Q = 20.0  # Factor de Calidad
# Diseño de filtro notch
b, a = iirnotch(f0, Q, Fs)
y = lfilter(b, a, emg_senal)
#y = lfilter(b, a, y)

señalP = y
n = len(señalP)
t = np.arange(0,0+n,1)*Ts
plt.figure(figsize=(20,5))
plt.plot(t, señalP)
plt.ylabel("mV")
plt.xlabel("Tiempo [segundos]")
plt.title("Señal EMG filtrada mediante Filtro Notch")
# Out:
# Text(0.5, 1.0, 'Señal EMG filtrada mediante Filtro Notch')

# %%
emg_senal = y
Fs = 1000
Ts = 1/Fs
N = len(emg_senal)
yf = fft(emg_senal)
xf = np.linspace(0.0, 1.0/(2.0*Ts), N//2)
plt.figure(figsize=(15,5))
ejy = 2.0/N * np.abs(yf[0:N//2])
plt.plot(xf, ejy )
plt.grid()
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("Magnitud")
plt.title("Espectro de Magnitud de la señal EMG filtrada")
plt.xlim(-10,500)
plt.show()

# %%
# Filtrado

low_cutoff = 20
high_cutoff = 400

pre_pro_signal = bsnb.aux_functions._butter_bandpass_filter(y, low_cutoff, high_cutoff, Fs)

señalP = pre_pro_signal
n = len(señalP)
t = np.arange(0,0+n,1)*Ts
plt.figure(figsize=(20,5))
plt.plot(t, señalP)
plt.ylabel("mV")
plt.xlabel("Tiempo [segundos]")
plt.title("Señal EMG Filtrada mediante Filtro Pasabanda")
# Out:
# Text(0.5, 1.0, 'Señal EMG Filtrada mediante Filtro Pasabanda')

# %%
# Código empleado para generar los archivos numpy de las señales ya filtradas
señalS = señalP
data = {'señalS': señalS}
np.savez('ulnar2.npz',**data)

# %%
# Analizar el Fourier
emg_senal = pre_pro_signal
Fs = 1000
Ts = 1/Fs
N = len(emg_senal)
yf = fft(emg_senal)
xf = np.linspace(0.0, 1.0/(2.0*Ts), N//2)
plt.figure(figsize=(15,5))
ejy = 2.0/N * np.abs(yf[0:N//2])
plt.plot(xf, ejy )
plt.grid()
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("Magnitud")
plt.title("Espectro de Magnitud de la señal EMG filtrada")
plt.xlim(-10,500)
plt.show()

# %%
from statistics import stdev
# Umbral
avg_pre_pro_signal = mean(pre_pro_signal)
std_pre_pro_signal = stdev(pre_pro_signal)

# %%
# Deteccion de Activación
burst_begin, burst_end = bsnb.detect_emg_activations(señalP, Fs, smooth_level = 20, threshold_level = 10, time_units = True, plot_result = True)[:2]
# Out:
#   <div class="bk-root" id="0becb372-3e01-433f-9e89-d9bed06cfe88" data-root-id="1002"></div>

# %% [markdown]
# ## EXTRACCION DE CARACTERISTICAS

# %%
# Maximo
max_sample_value = max(señalP)
max_sample_value
# Out:
# 0.7037459058377166

# %%
# Minimo
min_sample_value = min(señalP)
min_sample_value
# Out:
# -0.8287302742660942

# %%
# Promedio

avg_sample_value = np.average(señalP)
avg_sample_value
# Out:
# 3.916104960074306e-06

# %%
# Desviacion estandar

std_sample_value = np.std(señalP)
std_sample_value
# Out:
# 0.09570232349616015

# %%
time_param_dict = {"Maximum EMG": max_sample_value, "Minimum EMG": min_sample_value, "Average EMG": avg_sample_value, "Standard Deviation EMG": std_sample_value}
time_param_dict
# Out:
# {'Maximum EMG': 0.7037459058377166,
#  'Minimum EMG': -0.8287302742660942,
#  'Average EMG': 3.916104960074306e-06,
#  'Standard Deviation EMG': 0.09570232349616015}

# %%
# Root Mean Square
from statistics import sqrt

rms = sqrt((sum(señalP*señalP))/len(señalP))
rms
# Out:
# 0.09570232357628289

# %%
# Area bajo la curva
from scipy import integrate
area = integrate.cumtrapz(señalP)
area
# Out:
# array([-0.00477868, -0.01082421, -0.01326511, ..., -0.01537094,
#        -0.00888268,  0.01886781])

# %%
# Potencia espectral de la señal
from scipy import signal
f, P = signal.welch(señalP, fs = Fs, window = 'hann', noverlap = 0, nfft = int(500.))
plt.figure(figsize=(20,5))
plt.plot(f, P)
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.title("EMG Power Spectral Density")
plt.show()

# %%
# potencia total
area_freq = integrate.cumtrapz(P, f, initial = 0)
total_power = area_freq[-1]
total_power
# Out:
# 0.008210486312758846

# %%
# Frecuencia Media

median_freq = f[np.where(area_freq >= total_power / 2)[0][0]]
median_freq
# Out:
# 168.0

# %%
f_max = f[np.argmax(P)]
f_max
# Out:
# 182.0
